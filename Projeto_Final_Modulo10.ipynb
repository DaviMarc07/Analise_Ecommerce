# %%
# ==============================
# 📊 Projeto Final - Módulo 10
# Visualização e análise de dados
# ==============================

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ==============================
# CONFIGURAÇÕES INICIAIS
# ==============================
sns.set_theme(style="whitegrid")
pd.set_option('display.max_columns', None)

# ==============================
# 1️⃣ LEITURA DOS DADOS
# ==============================
df = pd.read_csv("ecommerce_preparados.csv")

# ==============================
# 2️⃣ INFORMAÇÕES GERAIS
# ==============================
print("=== INFORMAÇÕES GERAIS DO DATASET ===")
print(df.info(), "\n")

# ==============================
# 3️⃣ ESTATÍSTICAS DESCRITIVAS
# ==============================
print("=== ESTATÍSTICAS DESCRITIVAS ===")
print(df.describe(), "\n")

# ==============================
# 4️⃣ GRÁFICOS
# ==============================

# 🔹 Histograma – distribuição dos preços
plt.figure(figsize=(8, 5))
sns.histplot(df["Preço"].dropna(), bins=30, kde=True, color="skyblue")
plt.title("Distribuição de Preços")
plt.xlabel("Preço (R$)")
plt.ylabel("Frequência")
plt.tight_layout()
plt.show()

# 🔹 Gráfico de Dispersão – relação entre Preço e Nota
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="Preço", y="Nota", alpha=0.6, color="teal")
plt.title("Relação entre Preço e Nota")
plt.xlabel("Preço (R$)")
plt.ylabel("Nota Média")
plt.tight_layout()
plt.show()

# 🔹 Mapa de Calor – correlação entre variáveis numéricas
plt.figure(figsize=(10, 7))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Mapa de Calor das Correlações")
plt.tight_layout()
plt.show()

# 🔹 Gráfico de Barras – top 10 marcas mais frequentes
top_marcas = df["Marca"].value_counts().head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_marcas.index, y=top_marcas.values, hue=top_marcas.index, palette="viridis", legend=False)
plt.title("Top 10 Marcas Mais Frequentes")
plt.xlabel("Marca")
plt.ylabel("Frequência")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 🔹 Gráfico de Pizza – proporção de produtos por temporada
plt.figure(figsize=(7, 7))
df["Temporada"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90,
    colors=sns.color_palette("pastel")
)
plt.title("Distribuição de Produtos por Temporada")
plt.ylabel("")
plt.tight_layout()
plt.show()

# 🔹 Gráfico de Densidade – distribuição da nota dos produtos
plt.figure(figsize=(8, 5))
sns.kdeplot(df["Nota"].dropna(), fill=True, color="green")
plt.title("Densidade das Notas dos Produtos")
plt.xlabel("Nota")
plt.ylabel("Densidade")
plt.tight_layout()
plt.show()

# 🔹 Gráfico de Regressão – relação entre Desconto e Preço
plt.figure(figsize=(8, 5))
sns.regplot(
    data=df,
    x="Desconto",
    y="Preço",
    scatter_kws={"alpha": 0.5},
    line_kws={"color": "red"}
)
plt.title("Relação entre Desconto e Preço dos Produtos")
plt.xlabel("Desconto (%)")
plt.ylabel("Preço (R$)")
plt.tight_layout()
plt.show()

# ==============================
# 5️⃣ ANÁLISE AUTOMÁTICA
# ==============================
print("\n=== ANÁLISE AUTOMÁTICA ===")

# Correlação geral
corr = df.corr(numeric_only=True)

# Insight 1 – Preço x Nota
if "Preço" in corr.columns and "Nota" in corr.columns:
    preco_nota = corr.loc["Preço", "Nota"]
    if preco_nota < -0.3:
        print(f"→ Produtos com preços mais altos tendem a ter notas mais baixas (correlação {preco_nota:.2f}).")
    elif preco_nota > 0.3:
        print(f"→ Produtos mais caros tendem a receber notas mais altas (correlação {preco_nota:.2f}).")
    else:
        print(f"→ O preço e a nota não têm relação significativa (correlação {preco_nota:.2f}).")

# Insight 2 – Desconto x Preço
if "Desconto" in corr.columns and "Preço" in corr.columns:
    preco_desc = corr.loc["Desconto", "Preço"]
    if preco_desc < -0.3:
        print(f"→ Produtos com maiores descontos têm preços mais baixos (correlação {preco_desc:.2f}).")
    elif preco_desc > 0.3:
        print(f"→ Produtos com maiores descontos são, em geral, os mais caros (correlação {preco_desc:.2f}).")
    else:
        print(f"→ Descontos e preços não têm correlação forte (correlação {preco_desc:.2f}).")

# Insight 3 – Nota média
nota_media = df["Nota"].mean()
print(f"→ A nota média geral dos produtos é {nota_media:.2f}.")

# Insight 4 – Marcas mais populares
marca_top = df["Marca"].mode()[0]
print(f"→ A marca mais frequente no conjunto de dados é '{marca_top}'.")

# Insight 5 – Temporada dominante
temporada_top = df["Temporada"].mode()[0]
print(f"→ A temporada com mais produtos é '{temporada_top}'.")

print("\n✅ Análise concluída com sucesso! Todos os gráficos e insights foram gerados.")
